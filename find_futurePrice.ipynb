# %%
"""
Finding the Future price on the given day t and t-1 
"""

import pandas as pd
df = pd.read_excel("find_futurePrice.xlsx")
df.head()
# Out:
#           FFU89 Comdty Unnamed: 1         FFV89 Comdty Unnamed: 3  \
# 0                 Date    PX_LAST                 Date    PX_LAST
# 1                  NaN      90.84                  NaN       90.1
# 2  1989-01-04 00:00:00      90.64  1989-05-02 00:00:00      90.13
# 3  1989-01-05 00:00:00      90.59  1989-05-03 00:00:00      90.18
# 4  1989-01-06 00:00:00      90.55  1989-05-04 00:00:00      90.19
#
#           FFX89 Comdty Unnamed: 5         FFF90 Comdty Unnamed: 7  \
# 0                 Date    PX_LAST                 Date    PX_LAST
# 1                  NaN      90.83                  NaN      91.52
# 2  1989-06-01 00:00:00       90.8  1989-08-25 00:00:00      91.52
# 3  1989-06-02 00:00:00      91.15  1989-08-28 00:00:00       91.5
# 4  1989-06-05 00:00:00      91.13  1989-08-29 00:00:00      91.43
#
#           FFG90 Comdty Unnamed: 9     ...              FFU16 Comdty  \
# 0                 Date    PX_LAST     ...                      Date
# ...

# %%
import datetime
lst = [i.to_datetime().month+3 for i in date.ix[:,0]]
lst_year = [i.to_datetime().year for i in date.ix[:,0]]
ticker=[]
for i in xrange(len(lst)):
    if lst[i]==1:
        temp = "FFF"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==2:
        temp = "FFG"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==3:
        temp = "FFH"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==4:
        temp = "FFJ"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==5:
        temp = "FFK"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==6:
        temp = "FFM"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==7:
        temp = "FFN"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==8:
        temp = "FFQ"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==9:
        temp = "FFU"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==10:
        temp = "FFV"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==11:
        temp = "FFX"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==12:
        temp = "FFZ"+str(lst_year[i])[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==13:
        temp = "FFF"+str(lst_year[i]+1)[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==14:
        temp = "FFG"+str(lst_year[i]+1)[2:]+" Comdty"
        ticker.append(temp)
    if lst[i]==15:
        temp = "FFH"+str(lst_year[i]+1)[2:]+" Comdty"
        ticker.append(temp)
import datetime
date = pd.read_excel("date.xlsx")
date["ticker"]=ticker
date.head()
# Out:
#         Date        ticker
# 0 1989-06-06  FFU89 Comdty
# 1 1989-07-07  FFV89 Comdty
# 2 1989-07-27  FFV89 Comdty
# 3 1989-08-22  FFX89 Comdty
# 4 1989-10-03  FFF90 Comdty

# %%
def get_price_idx(df,future_name):
    for col_idx in xrange(len(df.columns)):
        if df.columns[col_idx]==future_name:
            return col_idx+1
n = len(date)
count=0
for i in xrange(244):
    future_name = date.ix[i,1]
    price_idx = get_price_idx(df,future_name)
    for j in xrange(len(df.ix[:,future_name])):
        if date.ix[i,0]==df.ix[j,future_name]:
            count+=1
            print df.ix[j,price_idx],df.ix[j-1,price_idx],future_name,count
            break
print count
# Out:
# 91.14 91.12 FFU89 Comdty 1
# 91.62 91.56 FFV89 Comdty 2
# 91.7 91.62 FFV89 Comdty 3
# 91.29 91.33 FFX89 Comdty 4
# 91.26 91.22 FFF90 Comdty 5
# 91.7 91.73 FFF90 Comdty 6
# 91.65 91.7 FFG90 Comdty 7
# 91.88 91.83 FFG90 Comdty 8
# 92.04 91.97 FFH90 Comdty 9
# 91.77 91.78 FFK90 Comdty 10
# 91.62 91.64 FFM90 Comdty 11
# 91.72 91.72 FFQ90 Comdty 12
# 91.95 91.95 FFV90 Comdty 13
# 92.08 92 FFV90 Comdty 14
# 92.1 92.14 FFX90 Comdty 15
# 92.31 92.28 FFF91 Comdty 16
# 92.31 92.29 FFF91 Comdty 17
# 92.53 92.52 FFG91 Comdty 18
# 92.87 92.7 FFH91 Comdty 19
# 93.07 92.93 FFH91 Comdty 20
# 93.37 93.28 FFJ91 Comdty 21
# 93.77 93.58 FFK91 Comdty 22
# 93.82 93.82 FFK91 Comdty 23
# 93.89 93.76 FFM91 Comdty 24
# 93.87 93.89 FFM91 Comdty 25
# 94.18 94.06 FFN91 Comdty 26
# 94.15 94.16 FFQ91 Comdty 27
# 93.94 93.92 FFV91 Comdty 28
# 94.43 94.32 FFX91 Comdty 29
# 94.63 94.61 FFX91 Comdty 30
# 94.6 94.52 FFZ91 Comdty 31
# 94.75 94.74 FFF92 Comdty 32
# 95.02 95.03 FFF92 Comdty 33
# ...
